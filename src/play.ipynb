# %% [markdown]
# # Monster Chess — Play Against the AI
#
# Run **Setup** and **Helpers** once, then run **Play** for each new game. Type moves in the text box below the board and press Enter.

# %%
# === Setup (run once) ===
import torch
import os, sys, json, time, threading, glob
import chess, chess.svg
import ipywidgets as widgets
from IPython.display import display, SVG, HTML

from config import MODEL_DIR, RAW_DATA_DIR
from monster_chess import MonsterChessGame
from mcts import MCTS
from evaluation import evaluate

# --- Configuration ---
PLAY_AS = "black"         # "black" or "white"
SIMULATIONS = 400         # MCTS search depth (400 = benchmark/anchor config)
SAVE_DIR = f"data/raw/human_games/{PLAY_AS}_2026_07"    # dated subdir under human_games

# --- Evaluator selection widget ---
def _discover_model_choices():
    choices = [("Heuristic", None)]

    # Current/top-level models (e.g., best_value_net.pt)
    top_level_models = sorted(glob.glob(os.path.join(MODEL_DIR, "*.pt")))
    for p in top_level_models:
        name = os.path.basename(p)
        label = f"current/{name}" if name == "best_value_net.pt" else f"models/{name}"
        choices.append((label, p))

    # Named run subdirectories (e.g., models/fresh_start_v8/best_value_net.pt)
    named_models = sorted(glob.glob(os.path.join(MODEL_DIR, "*", "best_value_net.pt")))
    for p in named_models:
        run_name = os.path.basename(os.path.dirname(p))
        if run_name != "candidates":
            choices.append((f"{run_name}/best_value_net.pt", p))

    # Rejected predecessors live under models/candidates/gen_*/best_value_net.pt
    candidate_models = sorted(glob.glob(os.path.join(MODEL_DIR, "candidates", "gen_*", "best_value_net.pt")))
    for p in candidate_models:
        gen_dir = os.path.basename(os.path.dirname(p))
        choices.append((f"candidate/{gen_dir}", p))

    return choices

_model_choices = _discover_model_choices()
_model_paths = [p for _label, p in _model_choices if p]

# Default: Heuristic (the aggressive anchor — strongest White, benchmark yardstick).
_default_eval = None

_eval_dropdown = widgets.Dropdown(
    options=_model_choices,
    value=_default_eval,
    description="Evaluator:",
    layout=widgets.Layout(width="520px"),
)
_status_label = widgets.HTML(value="")

def _load_evaluator(change=None):
    global eval_fn, engine
    model_path = _eval_dropdown.value
    if model_path is None:
        eval_fn = None
        _status_label.value = '<span style="font-family:monospace;color:#888">Using heuristic evaluation</span>'
    else:
        if not os.path.exists(model_path):
            _status_label.value = f'<span style="font-family:monospace;color:red">Model not found: {model_path}</span>'
            return
        from evaluation import NNEvaluator
        eval_fn = NNEvaluator(model_path)
        device = eval_fn.device.type
        short_name = os.path.relpath(model_path, MODEL_DIR).replace('\\', '/')
        _status_label.value = (
            f'<span style="font-family:monospace;color:#080">'
            f'Loaded <b>{short_name}</b> (device: {device})</span>'
        )
    # Human play: no Dirichlet root noise, early stop allowed (same as play.py)
    engine = MCTS(num_simulations=SIMULATIONS, eval_fn=eval_fn,
                  root_noise=False, allow_early_stop=True)

_eval_dropdown.observe(_load_evaluator, names="value")
_load_evaluator()  # initial load

# Heuristic-only engine for `auto` finishes: generated tails stay teacher-pure
# (no NN-vs-NN plies in the corpus) no matter which evaluator is selected.
auto_engine = MCTS(num_simulations=SIMULATIONS, eval_fn=None,
                   root_noise=False, allow_early_stop=True)

display(widgets.HBox([_eval_dropdown, _status_label]))
print(f"Playing as {PLAY_AS.upper()} | {SIMULATIONS} simulations")
if not _model_paths:
    print(f"(No .pt models found in {MODEL_DIR} or {os.path.join(MODEL_DIR, 'candidates')} — train one first to use NN eval)")
# Out:
# ...
# Playing as BLACK | 400 simulations

# %%
# === Helpers (run once) ===

def make_board_svg(board, last_move=None, flip=False, size=480):
    """Return SVG string for the board."""
    arrows = []
    if last_move:
        if isinstance(last_move, tuple):
            m1, m2 = last_move
            arrows.append(chess.svg.Arrow(m1.from_square, m1.to_square, color="#4a90d9aa"))
            if m2 != chess.Move.null():
                arrows.append(chess.svg.Arrow(m2.from_square, m2.to_square, color="#50c878aa"))
        else:
            arrows.append(chess.svg.Arrow(last_move.from_square, last_move.to_square, color="#4a90d9aa"))
    return chess.svg.board(board, arrows=arrows, flipped=flip, size=size, coordinates=True)


def make_eval_html(value):
    """Return HTML string for eval bar."""
    pct = max(2, min(98, int((value + 1) / 2 * 100)))
    if value > 0.3:
        label = f"<b>+{value:.2f}</b> White"
    elif value < -0.3:
        label = f"<b>{value:.2f}</b> Black"
    else:
        label = f"{value:.2f} Even"
    return f"""<div style="width:480px;height:22px;border:1px solid #888;border-radius:4px;overflow:hidden;display:flex;margin:4px 0">
      <div style="width:{pct}%;background:#eee"></div><div style="width:{100-pct}%;background:#333"></div>
    </div><div style="font-family:monospace;font-size:13px">{label}</div>"""


def parse_move(text, board, legal_set=None):
    """Parse UCI or SAN into a chess.Move.

    legal_set: if provided, only moves in this iterable are considered valid.
    When parse_san fails (e.g. king moves into check on White's first move, or
    king-captures-king — both legal in Monster Chess but rejected by python-chess's
    standard-chess validator), we fall back to matching the input against the SAN
    of each move in legal_set.  King moves additionally accept the no-'x' and
    lowercase forms ("Kd4"/"kxd4") — 'k' is not a file letter, so unambiguous.
    """
    text = text.strip()
    valid = set(legal_set) if legal_set is not None else None

    # --- UCI path (always tried first) ---
    try:
        move = chess.Move.from_uci(text)
        if valid is not None:
            if move in valid:
                return move
        elif move in board.pseudo_legal_moves or move in board.legal_moves:
            return move
    except (ValueError, chess.InvalidMoveError):
        pass

    # --- Standard SAN path ---
    try:
        move = board.parse_san(text)
        if valid is None or move in valid:
            return move
    except (ValueError, chess.InvalidMoveError, chess.AmbiguousMoveError):
        pass

    # --- Pseudo-legal SAN fallback ---
    # parse_san validates against board.legal_moves, which excludes moves that
    # are legal in Monster Chess but illegal in standard chess (king moves into
    # check on move 1, king-captures-king).  Match the input against the SAN
    # of each candidate move from legal_set (or pseudo_legal_moves).
    candidates = valid if valid is not None else board.pseudo_legal_moves
    clean = text.rstrip('+#')
    for move in candidates:
        # Try board.san() — may fail for positions with no king after the move.
        try:
            if board.san(move).rstrip('+#') == clean:
                return move
        except Exception:
            pass
        # Manual SAN fallback for king-captures-king (board.san can raise).
        piece = board.piece_at(move.from_square)
        if piece is None:
            continue
        is_cap = board.is_capture(move) or board.piece_at(move.to_square) is not None
        to_sq  = chess.square_name(move.to_square)
        if piece.piece_type == chess.PAWN:
            manual = (chr(ord('a') + chess.square_file(move.from_square)) + 'x' + to_sq
                      if is_cap else to_sq)
            if manual == clean:
                return move
        else:
            manual = piece.symbol().upper() + ('x' if is_cap else '') + to_sq
            if manual == clean:
                return move
            # King moves: accept the no-'x' capture form and lowercase input.
            if piece.piece_type == chess.KING and clean.lower() in (
                    "k" + to_sq, "kx" + to_sq):
                return move

    return None


def save_game(records, result, save_dir=None):
    """Save game records. save_dir defaults to data/raw/human_games."""
    for rec in records:
        rec["game_result"] = result
    if save_dir is None:
        out_dir = os.path.join(RAW_DATA_DIR, "human_games")
    elif os.path.isabs(save_dir):
        out_dir = save_dir
    else:
        project_root = os.path.dirname(os.path.dirname(RAW_DATA_DIR))
        out_dir = os.path.join(project_root, save_dir)
    os.makedirs(out_dir, exist_ok=True)
    existing = len([f for f in os.listdir(out_dir) if f.endswith(".jsonl")])
    path = os.path.join(out_dir, f"game_{existing:05d}.jsonl")
    with open(path, "w") as f:
        for rec in records:
            f.write(json.dumps(rec) + "\n")
    return path, len(records)


print("Helpers loaded.")
# Out:
# Helpers loaded.

# %% [markdown]
# ## Play a Game
#
# Run the cell below for each new game. Type moves in the text box (UCI like `e7e5` or SAN like `Nc6`) and press **Enter**. Type `quit` to resign.

# %%
# === PLAY (run for each new game) ===
# Synchronous loop: moves are typed into the kernel input prompt (VS Code /
# Jupyter focus it automatically — no clicking). The board updates IN PLACE
# via one display handle, so nothing re-renders or steals focus.
# Commands: auto = engine (heuristic) finishes both sides, real outcome saved;
#           skip = abandon without saving;  q = resign (honest loss).

from IPython.display import display, clear_output, HTML as _HTML
from play import ai_select_full_action, _winning_or_safe_pair_exists

def _panel(game, status, log, flip, eval_val=None, board_override=None):
    board = make_board_svg(board_override if board_override is not None else game.board,
                           flip=flip, size=440)
    bar = make_eval_html(eval_val) if eval_val is not None else ""
    rows = "".join(f"<div>{m}</div>" for m in log[-8:])
    return _HTML(
        f"{board}{bar}"
        f"<div style='font-family:monospace;font-size:14px;font-weight:bold;"
        f"margin:4px 0'>{status}</div>"
        f"<div style='font-family:monospace;font-size:12px;color:#666'>{rows}</div>"
    )

def play_loop(start_fen=None, play_as=None, save_dir=None):
    human_is_white = ((play_as or PLAY_AS) == "white")
    sdir = save_dir if save_dir is not None else SAVE_DIR
    game = MonsterChessGame(fen=start_fen) if start_fen else MonsterChessGame()
    flip = not human_is_white
    records, log = [], []

    # clear_output + fresh display each refresh: VS Code's renderer drops
    # update_display_data messages in some flows, so in-place handles go stale.
    def show(status, eval_val=None, board_override=None):
        clear_output(wait=True)
        display(_panel(game, status, log, flip, eval_val, board_override))

    show("starting...")

    def record(policy, value_side, is_white, actor):
        records.append({"fen": game.fen(), "mcts_value": round(value_side, 4),
                        "policy": policy, "current_player": "white" if is_white else "black",
                        "source": "human_game", "actor": actor})

    def finish(result, msg):
        extra = ""
        if records:
            path, n = save_game(records, result, save_dir=sdir)
            extra = f" — saved {n} positions to {os.path.basename(path)}"
        show(msg + extra)
        return result

    def eval_now():
        return evaluate(game) if eval_fn is None else eval_fn(game)

    def ai_move():
        is_white = game.is_white_turn
        show(f"AI ({'White' if is_white else 'Black'}) thinking...")
        t0 = time.time()
        # swindle=True: lost-position resistance (play-only; auto-finish and
        # all data/benchmark paths stay untouched).
        action, probs, val = ai_select_full_action(engine, game, temperature=0.1,
                                                   swindle=True)
        if action is None:
            return finish(0, "AI has no legal moves — stalemate!")
        record(probs, val, is_white, "ai")
        game.apply_action(action)
        if is_white:
            m1, m2 = action
            s = f"{m1.uci()}+{m2.uci()}" if m2 != chess.Move.null() else f"{m1.uci()} (king captured!)"
        else:
            s = action.uci()
        log.append(f"AI: {s}  [{time.time()-t0:.1f}s]")
        show(f"AI: {s} — your turn", eval_val=(val if is_white else -val))
        return None

    def auto_finish():
        plies = 0
        while not game.is_terminal() and plies < 600:
            if plies % 10 == 0:
                show(f"engines finishing... ply {plies}")
            is_white = game.is_white_turn
            fin = auto_engine if "auto_engine" in globals() else engine
            action, probs, val = ai_select_full_action(fin, game, temperature=0.1)
            if action is None:
                break
            record(probs, val, is_white, "ai")
            game.apply_action(action)
            plies += 1
        r = game.get_result()
        return finish(r, "White wins!" if r > 0 else "Black wins!" if r < 0 else "Draw (move limit)")

    def ask(prompt):
        try:
            return input(prompt).strip()
        except (EOFError, KeyboardInterrupt):
            return "skip"

    def game_end_check():
        if game.is_terminal():
            r = game.get_result()
            return finish(r, "White wins!" if r > 0 else "Black wins!" if r < 0 else "Draw")
        return None

    def human_black():
        legal = game.get_legal_actions()
        if not legal:
            return finish(0, "No legal moves — stalemate!")
        game.board.turn = chess.BLACK
        while True:
            t = ask("your move (or auto/skip/q): ")
            low = t.lower()
            if not t:
                continue
            if low == "skip":
                show("skipped — nothing saved.")
                return "skipped"
            if low == "auto":
                return auto_finish()
            if low in ("q", "quit", "resign"):
                return finish(1, "You resigned. White wins!")
            mv = parse_move(t, game.board, legal_set=legal)
            if mv is None or mv not in legal:
                hints = ", ".join(m.uci() for m in legal[:10])
                show(f"invalid: {t!r} — legal: {hints}...")
                continue
            record({mv.uci(): 1.0}, -eval_now(), False, "human")
            game.apply_action(mv)
            log.append(f"You: {mv.uci()}")
            show(f"you played {mv.uci()}")
            return None

    def human_white():
        board = game.board
        while True:  # m1
            board.turn = chess.WHITE
            legal1 = list(board.pseudo_legal_moves)
            t = ask("move 1/2 (or auto/skip/q): ")
            low = t.lower()
            if not t:
                continue
            if low == "skip":
                show("skipped — nothing saved.")
                return "skipped"
            if low == "auto":
                return auto_finish()
            if low in ("q", "quit", "resign"):
                return finish(-1, "You resigned. Black wins!")
            m1 = parse_move(t, board, legal_set=legal1)
            if m1 is None or m1 not in legal1:
                show(f"invalid move 1: {t!r}")
                continue
            board.push(m1)
            if board.king(chess.BLACK) is None:
                board.pop()
                action = (m1, chess.Move.null())
                record({f"{m1.uci()},{chess.Move.null().uci()}": 1.0}, eval_now(), True, "human")
                game.apply_action(action)
                log.append(f"You: {m1.uci()} (king captured!)")
                return game_end_check()
            board.pop()
            break
        while True:  # m2
            board.push(m1)
            board.turn = chess.WHITE
            legal2 = list(board.pseudo_legal_moves)
            # show the mid-pair board so m2 is chosen against the m1 position
            show(f"move 1: {m1.uci()} — enter move 2/2", board_override=board)
            t = ask(f"move 2/2 after {m1.uci()} (or q): ")
            low = t.lower()
            if low in ("q", "quit", "resign"):
                board.turn = chess.BLACK
                board.pop()
                return finish(-1, "You resigned. Black wins!")
            m2 = parse_move(t, board, legal_set=legal2)
            if m2 is None or m2 not in legal2:
                board.turn = chess.BLACK
                board.pop()
                show(f"invalid move 2: {t!r}")
                continue
            board.push(m2)
            captured_bk = board.king(chess.BLACK) is None
            wk = board.king(chess.WHITE)
            wk_attacked = wk is not None and board.is_attacked_by(chess.BLACK, wk)
            board.pop()
            board.turn = chess.BLACK
            board.pop()
            if (not captured_bk) and wk_attacked and _winning_or_safe_pair_exists(game):
                show("that leaves your king attacked — different move 2/2")
                continue
            action = (m1, m2)
            record({f"{m1.uci()},{m2.uci()}": 1.0}, eval_now(), True, "human")
            game.apply_action(action)
            log.append(f"You: {m1.uci()}+{m2.uci()}")
            show(f"you played {m1.uci()}+{m2.uci()}")
            return game_end_check()

    # main loop
    while True:
        if game.is_white_turn == human_is_white:
            r = human_white() if human_is_white else human_black()
        else:
            r = ai_move()
        if r is not None:
            return r
        r = game_end_check()
        if r is not None:
            return r


# standard game as PLAY_AS
play_loop()
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" viewBox="0 0 390 390" width="440" height="440"><desc><pre>r . . . k b . r
# . b K n . p p p
# p . . . p . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . q . .
# . . . . . . . .
# ...

# %% [markdown]
# ## Curriculum Session
#
# Serves deck positions (`tools/make_human_deck.py`) one at a time — you play the **side to move** vs the current evaluator. Play as many moves as you want, then:
#
# - **`auto`** — engine finishes both sides; the real outcome labels the whole game (your moves included). Fastest way to bank positions.
# - play to the end yourself for full demos, **`skip`** to discard, **`q`** to resign (counts as a loss — honest contrast data).
#
# Run **Deck** once (re-run to reload/reset), then run **Next position** for each new position. Everything saves to `data/raw/human_games/curriculum_2026_07/`.

# %%
# === Deck (run once; re-run to reload) ===
# Progress survives reloads: positions whose start FEN already appears as the
# first record of a saved curriculum game are skipped automatically.
DECK_FILE = "data/start_fens/human_deck_v2.jsonl"
CURRICULUM_SAVE_DIR = "data/raw/human_games/curriculum_2026_07"

_project_root = os.path.dirname(os.path.dirname(RAW_DATA_DIR))
_deck_path = DECK_FILE if os.path.isabs(DECK_FILE) else os.path.join(_project_root, DECK_FILE)
_key = lambda fen: " ".join(fen.split()[:2])

_played = set()
_cur_dir = os.path.join(_project_root, CURRICULUM_SAVE_DIR)
if os.path.isdir(_cur_dir):
    for _f in sorted(os.listdir(_cur_dir)):
        if _f.endswith(".jsonl"):
            with open(os.path.join(_cur_dir, _f), encoding="utf-8") as _fh:
                _first = _fh.readline()
            if _first.strip():
                _played.add(_key(json.loads(_first)["fen"]))

with open(_deck_path, encoding="utf-8") as _f:
    _all = [json.loads(ln) for ln in _f if ln.strip()]
DECK = [e for e in _all if _key(e["fen"]) not in _played]
DECK_IDX = 0
print(f"Deck: {len(_all)} positions, {len(_all)-len(DECK)} already played -> {len(DECK)} remaining")
from collections import Counter
for src_, n in sorted(Counter(e.get("source", "?") for e in DECK).items()):
    print(f"  {src_}: {n}")
# Out:
# Deck: 210 positions, 12 already played -> 198 remaining
#   own_offset_16: 33
#   own_offset_22: 25
#   own_offset_28: 20
#   own_offset_34: 10
#   own_offset_40: 3
#   pawnphase_black: 55
#   pawnphase_white: 52

# %%
# === Next position (run for each deck position) ===
# Opponent = v12 (falls back to heuristic if the model is missing).
_OPP = os.path.join(MODEL_DIR, "fresh_start_v15", "best_value_net.pt")

if DECK_IDX >= len(DECK):
    print("Deck exhausted — re-run the Deck cell to reset, or build a new deck.")
else:
    entry = DECK[DECK_IDX]
    DECK_IDX += 1
    _want = _OPP if os.path.exists(_OPP) else None
    if _eval_dropdown.value != _want:
        _eval_dropdown.value = _want   # triggers _load_evaluator -> rebuilds engine
    print(f"[{DECK_IDX}/{len(DECK)}] source={entry.get('source','?')} — "
          f"you play {entry['current_player'].upper()} vs {'v15' if _want else 'heuristic'}")
    play_loop(start_fen=entry["fen"], play_as=entry["current_player"],
              save_dir=CURRICULUM_SAVE_DIR)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" viewBox="0 0 390 390" width="440" height="440"><desc><pre>. r . q k b n .
# . p p b . p p .
# . . . . p . . .
# . . q . . . . .
# p . . P . . . r
# . . . . . . . .
# . . . . . . . .
# ...
